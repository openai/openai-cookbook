# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "glovida.com"
full_url = "https://www.glovida.com/"

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        # Create a list to store the hyperlinks
        self.hyperlinks = []

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)

        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser()
    parser.feed(html)

    return parser.hyperlinks

# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))


def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress

        # Save text from the url to a <url>.txt file
        with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w") as f:

            # Get the text from the URL using BeautifulSoup
            soup = BeautifulSoup(requests.get(url).text, "html.parser")

            # Get the text but remove the tags
            text = soup.get_text()

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")
            
            # Otherwise, write the text to the file in the text directory
            f.write(text)

        # Get the hyperlinks from the URL and add them to the queue
        for link in get_domain_hyperlinks(local_domain, url):
            if link not in seen:
                queue.append(link)
                seen.add(link)

crawl(full_url)
# Out:
# https://www.glovida.com/
# https://www.glovida.com/category/health
# https://www.glovida.com/products/ZBE1006/berocca-performance-orange-flavour-effervescent-tablets-30-s
# https://www.glovida.com/category/brands
# https://www.glovida.com/brands?name=Berocca
# https://www.glovida.com/login
# https://www.glovida.com/customer/account/forgotPassword
# https://www.glovida.com/register
# https://www.glovida.com/products/ZFL1006/fluimucil-a-600mg-effervescent-tablets-10s
# https://www.glovida.com/brands?name=Fluimucil
# https://www.glovida.com/products/ZFL1007/fluimucil-100mg-effervescent-granules-30s
# https://www.glovida.com/products/ZOC1005/ocean-health-d-vita-vitamin-d3-oral-spray-8ml
# https://www.glovida.com/brands?name=Ocean%20Health
# https://www.glovida.com/products/ZOC1006/zoc1006
# https://www.glovida.com/products/ZOC1004/ocean-health-high-strength-omega3-60s
# https://www.glovida.com/products/ZST1002/sterimar-baby-blocked-nose-50ml
# https://www.glovida.com/brands?name=Sterimar
# https://www.glovida.com/products/YUHE1001/herpatch-herpes-cold-sore-serum-5ml
# https://www.glovida.com/brands?name=Herpatch
# https://www.glovida.com/products/ZEG1001/ego-qv-cream-100g
# https://www.glovida.com/brands?name=Ego%20Qv
# https://www.glovida.com/products/ZEG1012/ego-qv-dermcare-eczema-daily-wash-with-ceramides-350ml
# https://www.glovida.com/products/ZEG1013/ego-qv-dermcare-eczema-daily-cream-with-ceramides-350ml
# https://www.glovida.com/products/ZEG1019/ego-qv-gentle-wash-1kg
# https://www.glovida.com/products/ZEG1005/ego-qv-skin-lotion-repair-250ml
# https://www.glovida.com/products/ZEG1007/ego-qv-flare-up-wash-150ml
# https://www.glovida.com/products/ZEG1006/ego-qv-flare-up-wash-150ml
# https://www.glovida.com/products/ZEG1004/ego-qv-skin-lotion-repair-500ml
# https://www.glovida.com/products/ZEG1022/ego-qv-baby-barrier-cream-125g
# https://www.glovida.com/products/ZEG1002/ego-qv-cream-pump-500g
# https://www.glovida.com/products/ZEG1016/ego-qv-baby-moisturing-cream-pump-500g
# https://www.glovida.com/products/ZSA1010/sambucol-black-elderberry-cold-flu-capsules-24-s
# https://www.glovida.com/brands?name=Sambucol
# https://www.glovida.com/products/ZSA1009/sambucol-black-elderberry-cold-flu-relief-kids-liquid-120ml
# https://www.glovida.com/products/ZSA1007/sambucol-elderberry-immune-defence-kids-gummies-50-s
# https://www.glovida.com/blog
# HTTP Error 404: Not Found
# https://www.glovida.com/products/ZSA1019/sambucol-black-elderberry-soothing-honey-lozenges-16-s
# https://www.glovida.com/products/ZSA1003/sambucol-elderberry-cold-flu-120ml
# https://www.glovida.com/products/ZSA1011/sambucol-black-elderberry-cold-flu-pain-relief-capsules-24-s
# https://www.glovida.com/products/ZSA1001/sambucol-black-elderberry-immune-defence-lozenge-20-s
# https://www.glovida.com/products/ZSA1008/sambucol-black-elderberry-cold-flu-forte-capsules-24-s
# https://www.glovida.com/products/ZSA1006/sambucol-black-elderberry-kids-cough-relief-120ml
# https://www.glovida.com/products/ZHE1001/heliocare-oral-sunscreen-ultra-caps-30-s
# https://www.glovida.com/brands?name=Heliocare
# https://www.glovida.com/products/ZHE1006/heliocare-360-gel-oil-free-spf-50-50ml
# https://www.glovida.com/products/ZHE1008/heliocare-pure-white-radiance-max240-fernblock
# https://www.glovida.com/products/ZHE1017/heliocare-ultra-d-oral-capsules-30-s
# https://www.glovida.com/products/ZHE1002/heliocare-ultra-90-gel-spf50+-50ml
# https://www.glovida.com/category2
# HTTP Error 404: Not Found
# https://www.glovida.com/products/ZSA1002/sambucol-cold-flu-elderberry-250ml
# https://www.glovida.com/products/ZPR1002/pro-uro-probiotics-28-s
# https://www.glovida.com/brands?name=Pro-Uro
# https://www.glovida.com/products/ZLE1003/leftose-syrup
# https://www.glovida.com/brands?name=Leftose
# https://www.glovida.com/products/ZLE1002/leftose-30-s-tablets
# https://www.glovida.com/products/ZLE1005/leftose-max-lozenges-blackcurrant-flavour-16s
# https://www.glovida.com/products/ZLE1001/leftose-black-elderberry-gummies-60-s
# https://www.glovida.com/products/ZLE1004/leftose-lozenges-honey-lemon-flavour-16-s
# https://www.glovida.com/products/ZTS1003/ts6-intensive-cleansing-mousse-180ml
# https://www.glovida.com/brands?name=TS6
# https://www.glovida.com/products/ZLA1008/lactomin-advance
# https://www.glovida.com/brands?name=Lactomin
# https://www.glovida.com/products/ZLA1011/lactocran-premium-cranberry-probiotics-30-s
# https://www.glovida.com/products/ZIS1001/isoderm-liquid-cleanser-with-pump-500ml
# https://www.glovida.com/brands?name=Isoderm
# https://www.glovida.com/products/ZIS1004/isoderm-baby-liquid-cleanser-250ml
# https://www.glovida.com/products/ZIS1003/isoderm-baby-liquid-cleanser-with-pump-500ml
# https://www.glovida.com/products/ZNC1001/nc2-native-collagen-ii-capsules-30-s
# https://www.glovida.com/brands?name=NC2
# https://www.glovida.com/products/ZCE1012/ceradan-ceramide-moisturising-wash-with-pump-280ml
# https://www.glovida.com/brands?name=Ceradan
# https://www.glovida.com/products/ZCE1013/ceradan-ceramide-skin-barrier-repair-cream-150g
# https://www.glovida.com/contacts
# HTTP Error 404: Not Found
# https://www.glovida.com/tel:+6594843356
# HTTP Error 404: Not Found
# https://www.glovida.com/products/ZCE1015/ceradan-diaper-cream-50g
# https://www.glovida.com/products/ZCE1017/ceramoz-mosquito-repellent-cream-50g
# https://www.glovida.com/products/ZOC1003/ocean-health-bicold-immune-support-for-kids-120ml
# https://www.glovida.com/products/ZHE1018/heliocare-360-capsules-30-s
# https://www.glovida.com/products/ZUL1003/ultra-guard-children-surgical-face-mask-50-s
# https://www.glovida.com/brands?name=Ultra%20Guard
# https://www.glovida.com/products/ZTS1001/ts6-probiotic
# https://www.glovida.com/products/ZLA1009/lactokids
# https://www.glovida.com/products/ZST1001/sterimar-baby-nasal-hygiene-spray-50ml
# https://www.glovida.com/products/ZPI1001/piascledine-300mg-capsules-30-s
# https://www.glovida.com/brands?name=Piascledine
# https://www.glovida.com/products/ZSA1004/sambucol-elderberry-immuno-forte-250ml
# https://www.glovida.com/products/ZUL1002/ultra-guard-3-ply-surgical-face-mask-50s
# https://www.glovida.com/products/ZVI1002/vivomixx-probiotics-caps-30-s
# https://www.glovida.com/brands?name=Vivomixx
# https://www.glovida.com/products/ZVI1008/vivomixx-probiotics-drop-with-vitamin-d3-10ml
# https://www.glovida.com/products/ZVI1007/vivomixx-probiotics-kids-sachets-20-s
# https://www.glovida.com/products/ZIS1002/isoderm-liquid-cleanser-250ml
# https://www.glovida.com/products/ZCE1011/ceradan-ceramide-hydra-moisturiser-80g
# https://www.glovida.com/products/ZUV1001/ultravite-boswellia-ginger-complex-capsules-60-s
# https://www.glovida.com/brands?name=Ultravite
# https://www.glovida.com/products/ZVI1004/vivomixx-probiotics-sachets-30-s
# https://www.glovida.com/products/ZLU1003/lumecare-hypromellose-eye-drops-10ml
# https://www.glovida.com/brands?name=Lumecare
# https://www.glovida.com/products/ZLU1005/lumecare-eyelid-wipes-20-s
# https://www.glovida.com/products/ZLU1004/lumecare-carbomer-eye-gel-10g
# https://www.glovida.com/products/ZPH1007/physiogel-calming-relief-ai-restoring-lipid-balm-50ml
# https://www.glovida.com/brands?name=Physiogel
# https://www.glovida.com/products/ZPH1004/physiogel-calming-relief-ai-cream-100ml
# https://www.glovida.com/products/ZTS1002/ts6-probioticc
# https://www.glovida.com/products/ZCE1019/cetaphil-moisturising-lotion-1l
# https://www.glovida.com/brands?name=Cetaphil
# https://www.glovida.com/products/ZCE1020/cetaphil-sun-ultra-light-lotion-spf50-100ml
# https://www.glovida.com/products/ZCE1005/cetaphil-baby-daily-lotion-with-shea-butter-400ml
# https://www.glovida.com/products/ZCE1018/cetaphil-baby-gentle-wash-shampoo-400ml
# https://www.glovida.com/products/ZEG1017/ego-qv-baby-gentle-wash-500g
# https://www.glovida.com/category/hair-skin-care
# https://www.glovida.com/products/ZSU1004/sukin-natural-balance-shampoo-1l
# https://www.glovida.com/brands?name=Sukin
# https://www.glovida.com/products/ZSU1006/sukin-botanical-body-wash-1l
# https://www.glovida.com/products/ZSU1005/sukin-natural-balance-conditioner-1l
# https://www.glovida.com/products/ZHO1001/hope-s-relief-premium-eczema-cream-60g
# https://www.glovida.com/brands?name=Hope%27s%20Relief
# https://www.glovida.com/products/ZGA1004/gaia-natural-baby-conditioning-detangler-200ml
# https://www.glovida.com/brands?name=GAIA%20Natural%20Baby
# https://www.glovida.com/products/ZGA1005/gaia-natural-baby-shampoo-250ml
# https://www.glovida.com/products/ZGA1008/gaia-natural-baby-moisturiser-250ml
# https://www.glovida.com/products/ZVI1010/viviscal-gorgeous-growth-densifying-elixir-50ml
# https://www.glovida.com/brands?name=Viviscal
# https://www.glovida.com/products/ZVI1009/viviscal-gorgeous-growth-densifying-conditioner-250ml
# https://www.glovida.com/products/ZJA1006/jack-n-jill-natural-sunscreen-spf30-100g
# https://www.glovida.com/brands?name=Jack%20N%27%20Jill
# https://www.glovida.com/products/ZJA1005/jack-n-jill-natural-toothpaste-strawberry-50g
# https://www.glovida.com/products/ZJA1002/jack-n-jill-natural-toothpaste-bubble-gum-50g
# https://www.glovida.com/products/ZJA1004/jack-n-jill-natural-toothpaste-flavor-free-50g
# https://www.glovida.com/products/ZGA1007/gaia-natural-baby-sleeptime-bath-500ml
# https://www.glovida.com/products/ZBO1001/bonjela-gel-15g
# https://www.glovida.com/brands?name=Bonjela
# https://www.glovida.com/products/ZHI1003/hiruscar-gel-20g
# https://www.glovida.com/brands?name=Hiruscar
# https://www.glovida.com/products/ZHI1002/hiruscar-post-acne-gel-10g
# https://www.glovida.com/products/ZDR1001/drapolene-cream-55g
# https://www.glovida.com/brands?name=Drapolene
# https://www.glovida.com/products/ZTW1007/twinkle-multi-purpose-cleaner-spray-500ml
# https://www.glovida.com/brands?name=Twinkle
# https://www.glovida.com/products/ZTW1006/twinkle-hand-body-sanitizer-refill-pack-250ml
# https://www.glovida.com/products/ZTW1002/twinkle-baby-anti-dust-mite-room-linen-spray-100ml
# https://www.glovida.com/products/ZGL1001/gloves-in-a-bottle-dry-skin-eczema-shielding-lotion-100ml
# https://www.glovida.com/brands?name=Gloves%20In%20A%20Bottle
# https://www.glovida.com/products/ZGL1002/gloves-in-a-bottle-dry-skin-eczema-shielding-lotion-237ml
# https://www.glovida.com/products/ZTW1004/twinkle-hand-body-sanitizer-100ml
# https://www.glovida.com/products/ZOR1002/original-sprout-hair-body-baby-wash-946ml
# https://www.glovida.com/brands?name=Original%20Sprout
# https://www.glovida.com/products/ZOR1003/original-sprout-classic-shampoo-354mll
# https://www.glovida.com/products/ZOR1004/original-sprout-deep-conditioner-118ml
# https://www.glovida.com/products/ZOR1005/original-sprout-miracle-detangler-118ml
# https://www.glovida.com/products/ZMU1004/mustela-cicastela-moisture-recovery-cream-40ml
# https://www.glovida.com/brands?name=Mustela
# https://www.glovida.com/products/ZMU1006/mustela-hydra-bebe-body-lotion-500ml
# https://www.glovida.com/products/ZMU1003/mustela-no-rinse-cleansing-water-300ml
# https://www.glovida.com/products/ZMU1005/mustela-gentle-cleansing-gel-for-hair-body-500ml
# https://www.glovida.com/products/ZMU1002/mustela-vitamin-barrier-cream-100ml
# https://www.glovida.com/products/ZGA1006/gaia-natural-baby-bath-body-wash-500ml
# https://www.glovida.com/products/ZSE1005/sebamed-liquid-face-body-wash-1l
# https://www.glovida.com/brands?name=Sebamed
# https://www.glovida.com/products/ZSE1002/sebamed-anti-hairloss-shampoo-200ml
# https://www.glovida.com/subscribe-email
# https://www.glovida.com/terms-of-use
# https://www.glovida.com/category/dental-health
# https://www.glovida.com/products/YUIW1002/iwhite-instant2-teeth-whitening-kit-10-trays
# https://www.glovida.com/brands?name=Iwhite
# https://www.glovida.com/products/YUIW1004/iwhite-whitening-toothpaste-75ml
# https://www.glovida.com/products/YUOM1001/omical
# https://www.glovida.com/brands?name=Omical
# https://www.glovida.com/products/ZGC1002/gc-tooth-mousse-tutti-frutti-40g
# https://www.glovida.com/brands?name=GC%20Tooth%20Mousse
# https://www.glovida.com/products/ZGC1001/gc-tooth-mousse-strawberry-40g
# https://www.glovida.com/category/body-wash
# https://www.glovida.com/products/ZTH1022/thankyou-botanical-geranium-rosewood-body-wash-1l
# https://www.glovida.com/brands?name=Thankyou
# https://www.glovida.com/products/ZTH1005/thankyou-botanical-patchouli-vanilla-hand-wash-500ml
# https://www.glovida.com/products/ZTH1019/thankyou-botanical-lime-coriander-hand-wash-500ml
# https://www.glovida.com/products/ZTH1017/thankyou-botanical-sweet-orange-almond-hand-wash-500ml
# https://www.glovida.com/products/ZTH1016/thankyou-eexfoliating-hand-wash-botanical-geranium-rosewood-250ml
# https://www.glovida.com/products/ZTH1011/thankyou-botanical-cedarwood-clay-body-scrub-200g
# https://www.glovida.com/products/ZTH1014/thankyou-botanical-lemon-myrtle-goat-milk-hand-wash-500ml
# https://www.glovida.com/products/ZTH1018/thankyou-exfoliating-hand-wash-botanical-cedarwood-250ml
# https://www.glovida.com/products/ZTH1013/thank-you-botanical-%20lemon-myrtle-goat-milk-body-wash-500ml
# https://www.glovida.com/products/ZTH1020/thank-you-botanical-mint-spring-flowers-body-wash-1l
# https://www.glovida.com/products/ZTH1004/thankyou-botanical-mint-spring-flowers-body-wash-500ml
# https://www.glovida.com/products/ZTH1021/thankyou-botanical-sweet-orange-almond-body-wash-1l
# https://www.glovida.com/products/ZSU1008/suu-balm-dual-cooling-moisturising-cream-body-wash-840ml
# https://www.glovida.com/brands?name=Suu%20Balm
# https://www.glovida.com/products/ZTH1003/thankyou-botanical-geranium-rosewood-body-wash-500ml
# https://www.glovida.com/category/health-cough-cold
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/digestive-health
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/sanitizers-and-disinfectants
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/best-sellers
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/popular-brands-ceradan
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/popular-brands-vivomixx
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/supplements
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/beauty-skin-care
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/customer/account
# https://www.glovida.com/category/cleanser
# https://www.glovida.com/products/ZPA1006/papulex-moussant-soap-free-cleansing-gel-150ml
# https://www.glovida.com/brands?name=Papulex
# https://www.glovida.com/products/ZPA1005/papulex-oil-free-cream-40ml
# https://www.glovida.com/products/ZTD1001/tdf-acne-cleansing-powder-50g
# https://www.glovida.com/brands?name=TDF%20Derma%20Formula
# https://www.glovida.com/products/ZTD1004/tdf-light-textured-moisturizer-50g
# https://www.glovida.com/products/ZTD1002/tdf-aha-oily-acne-solution-8-100ml
# https://www.glovida.com/products/ZTD1003/tdf-ultra-light-hydrator-50g
# https://www.glovida.com/products/ZGL1003/glowfully-charcoal-beads-gel-cleanser-100ml
# https://www.glovida.com/brands?name=Glowfully
# https://www.glovida.com/products/ZGL1004/glowfully-h2o-jelly-mask-5-s
# https://www.glovida.com/products/ZGL1007/glowfully-deep-sea-glow-serum-30ml
# https://www.glovida.com/products/ZGL1008/glowfully-advanced-healing-elixir-night-gel-cream-50ml
# https://www.glovida.com/products/ZGL1009/glowfully-plumicious-brightening-serum-30ml
# https://www.glovida.com/products/ZGL1005/glowfully-healing-elixir-day-gel-cream-50ml
# https://www.glovida.com/products/YUSK1007/yusk1007
# https://www.glovida.com/brands?name=SkinB5
# https://www.glovida.com/products/YUSK1004/skinb5-extra-strength-acne-control-tablets-120s
# https://www.glovida.com/products/YUSK1005/skinb5-extra-strength-acne-control-tablets-60s
# https://www.glovida.com/products/YUSK1006/yusk1006
# https://www.glovida.com/products/YUSK1002/skinb5-acne-control-moisturiser-50ml
# https://www.glovida.com/products/YUSK1003/skinb5-acne-control-purifying-mask-100g
# https://www.glovida.com/products/ZNE1011/neostrata-pha-facial-cleanser-200ml
# https://www.glovida.com/brands?name=NeoStrata
# https://www.glovida.com/products/ZNE1010/neostrata-skin-active-triple-firming-neck-cream-80g
# https://www.glovida.com/products/ZNE1004/neostrata-mandelic-clarifying-cleanser-200ml
# https://www.glovida.com/products/ZNE1012/neostrata-bionic-face-serum-30ml
# https://www.glovida.com/products/ZNE1008/neostrata-gel-plus-125ml
# https://www.glovida.com/products/ZNE1003/neostrata-skin-active-intensive-eye-therapy-15g
# https://www.glovida.com/products/ZDE1003/dermsecrets-silver-ion-cleanser-150ml
# https://www.glovida.com/brands?name=Dermsecrets
# https://www.glovida.com/products/ZDE1002/dermsecrets-c-strength-10-15ml
# https://www.glovida.com/products/ZDE1004/dermsecrets-collagen-serum-15ml
# https://www.glovida.com/products/ZTH1008/thursday-plantation-tea-tree-face-wash-for-acne-150ml
# https://www.glovida.com/brands?name=Thursday%20Plantation
# https://www.glovida.com/products/ZTH1023/thursday-plantation-tea-tree-cold-sore-cream-10g
# https://www.glovida.com/products/ZTH1006/thursday-plantation-antiseptic-tea-tree-oil-50ml
# https://www.glovida.com/products/ZTH1007/thursday-plantation-calming-lavender-oil-50ml
# https://www.glovida.com/products/YUSK1001/skinb5-acne-control-cleansing-mousse-150ml
# https://www.glovida.com/category/popular-brands-thankyou
# https://www.glovida.com/category/treatment
# https://www.glovida.com/products/ZPI1003/pilose-revitalizing-follicle-spray-150ml
# https://www.glovida.com/brands?name=Pilose
# https://www.glovida.com/products/ZPI1004/pilose-condensed-activating-serum-50ml
# https://www.glovida.com/products/YUHA1004/hairmax-rsn8-pro-scalp-treatment-60ml
# https://www.glovida.com/brands?name=HairMax
# https://www.glovida.com/products/YUHA1003/hairmax-acceler8-hair-booster-nutrients-118ml
# https://www.glovida.com/products/YUHA1001/hairmax-stimul8-shampoo-300ml
# https://www.glovida.com/products/YUHA1002/hairmax-exhilar8-conditioner-300ml
# https://www.glovida.com/category/conditioner
# https://www.glovida.com/products/ZAV1025/aveda-botanical-repair-strengthening-conditioner-1l
# https://www.glovida.com/brands?name=Aveda
# https://www.glovida.com/products/ZAV1022/aveda-botanical-repair-strengthening-shampoo-200ml
# https://www.glovida.com/products/ZAV1007/aveda-invati-advanced-exfoliating-shampoo-rich-1l
# https://www.glovida.com/products/ZAV1012/aveda-invati-scalp-revitalizer-150ml
# https://www.glovida.com/products/ZAV1027/aveda-rosemary-mint-purifying-shampoo-1l
# https://www.glovida.com/products/ZAV1026/aveda-rosemary-mint-purifying-shampoo-250ml
# https://www.glovida.com/products/ZAV1023/aveda-botanical-repair-strengthening-shampoo-1l
# https://www.glovida.com/products/ZAV1008/aveda-invati-advanced-exfoliating-shampoo-rich-200ml
# https://www.glovida.com/products/ZAV1010/aveda-volumizing-tonic-100ml
# https://www.glovida.com/products/ZAV1024/aveda-botanical-repair-strengthening-conditioner-200ml
# https://www.glovida.com/products/ZAV1009/aveda-invati-conditioner-200ml
# https://www.glovida.com/products/ZAV1029/aveda-rosemary-mint-weightless-conditioner-250ml-1
# https://www.glovida.com/products/ZAV1028/aveda-rosemary-mint-weightless-conditioner-250ml
# https://www.glovida.com/products/ZAV1013/aveda-invati-thickening-conditioner-1l
# https://www.glovida.com/products/ZOL1004/olaplex-no-5-bond-maintenance-conditioner-250ml
# https://www.glovida.com/brands?name=Olaplex
# https://www.glovida.com/products/ZOL1005/olaplex-no-4-bond-maintenance-shampoo-250ml
# https://www.glovida.com/privacy-policy
# https://www.glovida.com/category/moms-kids-vitamins-supplements
# https://www.glovida.com/products/ZRE1008/redoxon-triple-action-effervescent-tablets-orange-flavour-45-s
# https://www.glovida.com/brands?name=Redoxon
# https://www.glovida.com/products/ZBR1001/braun-thermoscan-5-irt-6030-ear-thermometer
# https://www.glovida.com/brands?name=Braun
# https://www.glovida.com/products/ZEA1001/ease-a-cold-kids-cold-flu-chewable-tablets-24-s
# https://www.glovida.com/brands?name=Ease-A-Cold
# https://www.glovida.com/products/ZEA1003/ease-a-cold-cough-cold-flu-day-night-capsules-24-s
# https://www.glovida.com/products/ZSC1002/scott-s-emulsion-orange-flavour-400ml
# https://www.glovida.com/brands?name=Scott%27s
# https://www.glovida.com/products/ZSC1001/scott-s-emulsion-original-400ml
# https://www.glovida.com/products/ZGA1003/ganilia-soft-gel-for-pregnancy-lactation-60-s
# https://www.glovida.com/brands?name=Ganilia
# https://www.glovida.com/products/YUMO1004/motherlove-more-milk-special-blend-capsules-120-s
# https://www.glovida.com/brands?name=Motherlove
# https://www.glovida.com/products/YUMO1002/motherlove-more-milk-plus-capsules-120-s
# https://www.glovida.com/products/ZSC1003/scott-s-dha-gummies-strawberry-flavour-60-s
# https://www.glovida.com/products/ZEN1001/enervon-c-kidz-multivitamin-syrup-120ml
# https://www.glovida.com/brands?name=Enervon
# https://www.glovida.com/products/ZNE1001/neurobion-ablets-30-s
# https://www.glovida.com/brands?name=Neurobion
# https://www.glovida.com/products/ZPR1006/promensil-menopause-double-strength-tablets-60-s
# https://www.glovida.com/brands?name=Promensil
# https://www.glovida.com/products/ZIM1001/immunped-syrup-60ml-pediatech
# https://www.glovida.com/brands?name=Immunped
# https://www.glovida.com/products/YUMO1001/motherlove-more-milk-plus-capsules-60-s
# https://www.glovida.com/products/ZHE1014/herbs-of-gold-grape-seed-gold-tablets-60-s
# https://www.glovida.com/brands?name=Herbs%20Of%20Gold
# https://www.glovida.com/products/ZEA1002/ease-a-cold-kids-cough-cold-flu-relief-120ml
# https://www.glovida.com/products/ZEN1002/enervon-with-vitamin-c-caplets-30-s
# https://www.glovida.com/products/ZBL1007/blackmores-pregnancy-breast-feeding-gold-60-s
# https://www.glovida.com/brands?name=Blackmores
# https://www.glovida.com/products/ZBL1019/blackmores-multivitamins-for-women-tablets-90s
# https://www.glovida.com/products/ZBL1009/blackmores-echinacea-ace-zinc-tablets-60-s
# https://www.glovida.com/products/ZIB1001/iberet-folic-500-tablets-60-s
# https://www.glovida.com/brands?name=Iberet
# https://www.glovida.com/products/YUMO1003/motherlove-more-milk-special-blend-capsules-60-s
# https://www.glovida.com/category/popular-brands-aveda
# https://www.glovida.com/category/best-sellers-kids
# https://www.glovida.com/products/ZLA1003/lactogg-probiotics
# https://www.glovida.com/brands?name=LactoGG
# https://www.glovida.com/products/ZLA1010/lactogg-probiotics
# https://www.glovida.com/category/eczema-care
# https://www.glovida.com/products/ZYN001/y-not-natural-omega-369-oil-australian-emu-oil-60ml
# https://www.glovida.com/brands?name=Y-Not%20Natural
# https://www.glovida.com/products/YUAC1001/acuralle-aloe-vera-gel-100ml
# https://www.glovida.com/brands?name=Acuralle
# https://www.glovida.com/products/ZIN1001/inner-health-eczema-skin-shield-capsules-30-s
# https://www.glovida.com/brands?name=Inner%20Health
# https://www.glovida.com/products/ZIN1002/inner-health-digestive-defence-capsules-60-s
# https://www.glovida.com/category/beauty-hair-care
# https://www.glovida.com/products/ZRE1006/regro-5-hair-lotion-80ml
# https://www.glovida.com/brands?name=ReGro
# https://www.glovida.com/products/ZGR1001/growell-5-scalp-lotion-100ml
# https://www.glovida.com/brands?name=Growell
# https://www.glovida.com/category/shampoo
# https://www.glovida.com/category/popular-brands-heliocare
# https://www.glovida.com/category/body-oil
# https://www.glovida.com/category/australian-brands
# https://www.glovida.com/category/beauty
# https://www.glovida.com/checkout/cart
# https://www.glovida.com/category/moms-kids
# https://www.glovida.com/brand
# https://www.glovida.com/brands?name=Actal
# https://www.glovida.com/products/ZAC1001/actal-fast-acting-antacid-tablets-20-s
# https://www.glovida.com/brands?name=Nurofen
# https://www.glovida.com/products/ZNU1002/nurofen-coated-tablets-12-s
# https://www.glovida.com/products/ZNU1001/nurofen-children-oral-suspension-orange-flavour-60ml
# https://www.glovida.com/brands?name=Flo
# https://www.glovida.com/products/ZFL1008/flo-sinus-care-refill-pack-50-s
# https://www.glovida.com/products/ZFL1003/flo-baby-saline-nasal-spray-15ml
# https://www.glovida.com/products/ZFL1004/flo-kids-saline-nasal-spray-15ml
# https://www.glovida.com/brand#C
# https://www.glovida.com/brands?name=Colpermin
# https://www.glovida.com/products/ZCO1011/colpermin-ibs-peppermint
# https://www.glovida.com/brands?name=NeilMed
# https://www.glovida.com/products/ZNE1005/neilmed-sinus-rinse-kit-with-60-premixed-sachets
# https://www.glovida.com/brand#D
# https://www.glovida.com/brand#Y
# https://www.glovida.com/brands?name=Oxithion
# https://www.glovida.com/products/ZOX1001/oxithion-sublingual-tablets-30-s
# https://www.glovida.com/brand#I
# https://www.glovida.com/brands?name=Mucosolvan
# https://www.glovida.com/products/ZMU1001/mucosolvan-24-hours-cough-relief-capsules-10-s
# https://www.glovida.com/brands?name=Voltaren
# https://www.glovida.com/products/ZVO1001/voltaren-back-muscle-pain-emulgel-50g
# https://www.glovida.com/brand#A
# https://www.glovida.com/brands?name=Euky%20Bear
# https://www.glovida.com/products/ZEU1003/euky-bear-sniffly-nose-room-spray-125g
# https://www.glovida.com/brand#P
# https://www.glovida.com/brands?name=EZZ%20NMN
# https://www.glovida.com/products/YEZZ1001/ezz-nmn-150000mcg-tablets-60-s
# https://www.glovida.com/brands?name=Lacteol%20Fort
# https://www.glovida.com/products/ZLA1007/lacteol-fortprobiotics-sachet-100-s
# https://www.glovida.com/products/ZLA1006/lacteol-fort-caps-probiotics-100-s
# https://www.glovida.com/brand#T
# https://www.glovida.com/brand#H
# https://www.glovida.com/brand#O
# https://www.glovida.com/brand#J
# https://www.glovida.com/brands?name=Flexiseq
# https://www.glovida.com/products/ZFL1001/flexiseq-gel-50g
# https://www.glovida.com/brands?name=Difflam
# https://www.glovida.com/products/ZDI1001/difflam-anti-inflammatory-anti-bacterial-lozenges-eucalyptus-menthol-flavour-16-s
# https://www.glovida.com/brands?name=Artrex
# https://www.glovida.com/products/ZAR1001/artrex-ds-boswellia-joints-60-s
# https://www.glovida.com/brand#E
# https://www.glovida.com/brand#S
# https://www.glovida.com/brand#B
# https://www.glovida.com/brands?name=Duolac
# https://www.glovida.com/products/ZDU1006/duolac-derma-probiotics-30-s
# https://www.glovida.com/brand#M
# https://www.glovida.com/brands?name=Pro-Gut
# https://www.glovida.com/products/ZPR1007/pro-gut-probiotics-capsules-100-s
# https://www.glovida.com/brands?name=Zyrtec
# https://www.glovida.com/products/ZZY1001/zyrtec-r-tablets-10mg-10-s
# https://www.glovida.com/products/ZZY1004/zyrtec-r-oral-solution-banana-flavour-75ml
# https://www.glovida.com/brands?name=Iliadin
# https://www.glovida.com/products/ZIL1001/iliadin-decongestant-nasal-baby-drops-0-01-5ml
# https://www.glovida.com/brand#L
# https://www.glovida.com/brands?name=Brufen
# https://www.glovida.com/products/ZBR1004/brufen-oral-suspension-60ml
# https://www.glovida.com/brands?name=UC-II
# https://www.glovida.com/products/ZUC1001/uc-ii-original-40mg-capsules-30-s
# https://www.glovida.com/brand#R
# https://www.glovida.com/brand#Z
# https://www.glovida.com/brands?name=YourgutPlus
# https://www.glovida.com/products/YUYO1001/yourgutplus-capsules-60-s
# https://www.glovida.com/brands?name=Remescar
# https://www.glovida.com/products/YURE1003/remescar-scar-stick-10g
# https://www.glovida.com/products/YURE1001/remescar-eye-bags-and-dark-circles-8ml
# https://www.glovida.com/brands?name=Nasaval%20
# https://www.glovida.com/products/YUNA1001/yuna1001
# https://www.glovida.com/brand#U
# https://www.glovida.com/brands?name=Ginflex
# https://www.glovida.com/products/ZGI1001/ginflex-capsules-30-s
# https://www.glovida.com/brands?name=Evolve
# https://www.glovida.com/products/ZEV1001/evolve-ha-intensive-eye-drops-10ml
# https://www.glovida.com/products/ZEV1002/evolve-carmellose-soothing-eye-drops-10ml
# https://www.glovida.com/brands?name=Rhinathiol
# https://www.glovida.com/products/ZRH1001/rhinathiol-children-cough-syrup-raspberry-cherry-flavour-125ml
# https://www.glovida.com/brands?name=Fess
# https://www.glovida.com/products/ZFE1002/fess-children-s-saline-nasal-spray-20ml
# https://www.glovida.com/products/ZFE1001/fess-original-saline-nasal-spray-30ml
# https://www.glovida.com/brand#N
# https://www.glovida.com/brands?name=Hylo-Comod
# https://www.glovida.com/products/ZHY1001/hylo-comod-lubricating-eye-drops-10ml
# https://www.glovida.com/brands?name=Ural
# https://www.glovida.com/products/ZUR1001/ural-effervescent-granules-4gm-28-s
# https://www.glovida.com/brands?name=Nature%27s%20Own
# https://www.glovida.com/products/ZNA1004/nature-s-own-double-strength-cold-sore-relief-tablets-100-s
# https://www.glovida.com/brand#G
# https://www.glovida.com/brands?name=Tiger%20Balm
# https://www.glovida.com/products/ZTI1003/tiger-balm-mosquito-repellant-spray-60ml
# https://www.glovida.com/products/ZTI1002/tiger-balm-mosquito-repellent-patch-22-s
# https://www.glovida.com/brands?name=Duphalac
# https://www.glovida.com/products/ZDU1005/duphalac-lactulose-oral-solution-1000ml
# https://www.glovida.com/brand#V
# https://www.glovida.com/brands?name=Telfast
# https://www.glovida.com/products/ZTE1004/telfast-allergy-relief-tablets-10-s
# https://www.glovida.com/brands?name=Heptral
# https://www.glovida.com/products/ZHE1016/heptral-400mg-tablets-30-s
# https://www.glovida.com/brand#F
# https://www.glovida.com/category/popular-brands-viviscal
# https://www.glovida.com/category/sunscreen
# https://www.glovida.com/category/popular-brands-egoqv
# https://www.glovida.com/category/beauty-oral-supplements
# https://www.glovida.com/category/popular-brands-blackmores
# https://www.glovida.com/category/serum
# https://www.glovida.com/category/moms-kids-cough-cold
# https://www.glovida.com/about
# https://www.glovida.com/category/moms-kids-probiotics
# https://www.glovida.com/category/hand-care
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/bath-and-body-sets
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/moms-kids-immunity-boosters
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/rewards/myRewards
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/health-eye-care
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/joint-health
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/covid-necessities
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/popular-brands-sambucol
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/popular-brands
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/hair-care-sets
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/best-sellers-beauty
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/mosquito-repellent
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category-mobile
# HTTP Error 502: Bad Gateway
# https://www.glovida.com/category/masks
# https://www.glovida.com/category/health-immunity-boosters
# https://www.glovida.com/category/clinic-exclusives
# https://www.glovida.com/category/feminine-care
# https://www.glovida.com/category/body-cream
# https://www.glovida.com/category/beauty-bath-body
# https://www.glovida.com/membership-benefits
# https://www.glovida.com/rewards/howtoEarn
# https://www.glovida.com/rewards/transactions
# https://www.glovida.com/customer/account/changePassword
# https://www.glovida.com/customer/edit
# https://www.glovida.com/customer/order-history
# https://www.glovida.com/customer/address
# https://www.glovida.com/customer/review
# https://www.glovida.com/category/sun-care
# https://www.glovida.com/category/allergy-care
# https://www.glovida.com/category/clearance-sale
# https://www.glovida.com/category/moms-kids-fever-pain-relief
# https://www.glovida.com/category/moisturiser
# https://www.glovida.com/category/health-vitamins-supplements
# https://www.glovida.com/category/body-lotion
# https://www.glovida.com/article
# https://www.glovida.com/article/staying-healthy-became-so-much-easier-with-glovida
# https://www.glovida.com/article/buying-vitamins-supplements-online-how-careful-should-you-be-
# https://www.glovida.com/article/the-8-types-of-people-you-will-meet-this-christmas-the-practical-gift-guide-for-them
# https://www.glovida.com/brands/utama-spice.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/ceramiracle.html
# https://www.glovida.com/searchanise/result?q=sun+care&page=1&rb_categories=Heliocare+Photoprotection+Range
# HTTP Error 404: Not Found
# https://www.glovida.com/beauty/beauty-hair-care.html
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-olive-oil-hand-lotion-with-essential-oils-of-lemon-myrtle-avocado-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-olive-oil-liquid-soap-with-essential-oils-of-lemon-myrtle-avocado-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/health/digestive-health.html
# https://www.glovida.com/brands/utena.html
# https://www.glovida.com/blackmores-odourless-fish-oil-mini-capsules-400-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/searchanise/result?q=coconut+oil
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/recherche.html
# https://www.glovida.com/brands/vasse-virgin.html
# https://www.glovida.com/brands/auolive.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-pure-natural-essential-oil-diffuser-rose-vanilla-lavender-lemon.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/heliocare.html
# HTTP Error 500: RuntimeError
# https://www.glovida.com/beauty/beauty-oral-supplements.html
# https://www.glovida.com/beauty/beauty-skin-care.html?limit=36&p=2
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-chamomile-lavender-therapeutic-olive-oil-bath-massage-oil.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/ceramiracle/ceramiracle-first-light-the-reboot-mask-100g.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/ouch-best-pain-relieving-supplements-for-joint-pain
# https://www.glovida.com/piascledine-300mg-capsules-30-s.html
# https://www.glovida.com/flexiseq-gel-50g.html
# HTTP Error 404: Not Found
# https://www.glovida.com/artrex-ds-boswellia-joints-60-s.html
# https://www.glovida.com/uc-ii-40mg-capsule-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/omical.html
# https://www.glovida.com/ultravite-boswellia-ginger-complex.html
# https://www.glovida.com/article/forget-yakult-here-are-the-best-probiotic-supplements-for-you
# https://www.glovida.com/bio15.html
# HTTP Error 500: RuntimeError
# https://www.glovida.com/brands/lactogg.html
# https://www.glovida.com/natures-way-kids-smart-probiotic-choc-balls-50s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/biogaia.html
# https://www.glovida.com/lactomin-advance.html
# https://www.glovida.com/brands/vivomixx/vivomixx-probiotics-sachets-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/pro-uro-probiotics-28-s.html
# https://www.glovida.com/brands/lacteol-fort.html
# https://www.glovida.com/lactokids-1117.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/pharmacist-a-mother-s-best-ally-when-it-comes-to-your-child-s-health
# https://www.glovida.com/article/beauty-skincare-you-can-eat-and-drink-what-to-know-and-10-brands-to-try
# https://www.glovida.com/article/glovida-glow-with-good-health
# https://www.glovida.com/article/paraben-free-sulfate-free-fragrance-free-products-what-are-they-do-they-actually-give-you-gorgeous-skin-
# https://www.glovida.com/ceramiracle-first-light-the-reboot-mask-100g.html
# HTTP Error 404: Not Found
# https://www.glovida.com/ceradan-wash-with-pump-280ml.html
# https://www.glovida.com/brands/ceradan.html
# https://www.glovida.com/auolive-day-glower-30ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/ego-qv-cream-pump-500g.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/ego-qv.html
# https://www.glovida.com/original-sprout-natural-shampoo-354ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/sukin-botanical-body-wash-1l.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/best-hair-products-that-keep-bad-hair-day-at-bay
# https://www.glovida.com/viviscal-professional-hair-nutritional-supplement-60-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/aveda-colorconserve-conditioner200ml.html
# HTTP Error 500: RuntimeError
# https://www.glovida.com/y-not-natural-moisture-repair-conditioner-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/utama-spice-argan-oil-30ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/ovelle-coconut-oil-100ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/y-not-natural-nourishing-shampoo-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/swisse-hair-skin-nails-tabs-60-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/blackmores-nails-hair-skin-tabs-60-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/aveda-colorconserve-shampoo1l.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/5-products-to-achieve-beauty-from-inside-out-u-weekly-singapore
# https://www.glovida.com/article/top-7-beauty-brands-you-have-to-know-in-2019
# https://www.glovida.com/brands/utena/utena-premium-puresa-golden-jelly-mask-hyaluronic-acid-3-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/glowfully-charcoal-beads-gel-cleanser-100ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/auolive/auolive-night-booster-30ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/utena/utena-premium-puresa-golden-jelly-mask-royal-jelly-3-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/ceramiracle/ceramiracle-flowerberry-eye-illuminating-supplement-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/aveda/aveda-invati-thickening-conditioner-1l.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/heliocare/heliocare-oral-sunscreen-ultra-caps-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/utena/utena-premium-puresa-golden-jelly-mask-rose-3-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/aveda/aveda-invati-scalp-revitalizer-150ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/utena/utena-premium-puresa-golden-jelly-mask-collagen-3-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/ceramiracle/ceramiracle-first-light-the-serum-30ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/aveda/aveda-invati-1liter.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/heliocare/heliocare-pure-white-radiance-max240-fernblock.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/aveda.html
# https://www.glovida.com/brands/auolive/auolive-day-glower-30ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/high-fever-in-children-when-to-seek-emergency-medical-attention-and-when-to-stay-at-home
# https://www.glovida.com/products/ZBR1004
# https://www.glovida.com/products/ZNU1001
# https://www.glovida.com/article/yucky-phlegm-the-3-best-expectorant-brands-for-phlegm-busting-
# https://www.glovida.com/brands/prospan/prospan-cough-syrup-for-children-200ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/prospan/prospan-cough-syrup-200ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/leftose/leftose-syrup.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/leftose/leftose-30-s-tablets-1082.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/fluimucil/fluimucil-a-600mg-effervescent-tablets-10s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/fluimucil/fluimucil-100mg-effervescent-granules-30s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/article/top-7-brands-for-eczema-and-sensitive-skin
# https://www.glovida.com/searchanise/result?q=physiogel
# HTTP Error 404: Not Found
# https://www.glovida.com/ceradan-hydra-cream-80g.html
# https://www.glovida.com/isoderm-liquid-cleanser-with-pump-500ml.html
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-kids-soothing-balm-100g.html
# HTTP Error 404: Not Found
# https://www.glovida.com/suu-balm-kids-head-to-toe-wash-420ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/y-not-natural-omega-369-oil-australian-emu-oil-60ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/vasse-virgin/vasse-virgin-chamomile-lavender-rejuvenating-olive-oil-moisturising-body-lotion-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/isoderm-baby-liquid-cleanser-250ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/gloves-in-a-bottle-dry-skin-eczema-shielding-lotion-100ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/suu-balm-itch-relieving-moisturizer-350ml.html
# HTTP Error 404: Not Found
# https://www.glovida.com/brands/cetaphil.html
# https://www.glovida.com/ceradan-cream-80g-skin-barrier.html
# HTTP Error 500: RuntimeError
# https://www.glovida.com/article/looking-for-a-clinic-exclusive-product-but-don-t-want-to-wait-in-line-for-a-doctor-you-may-just-be-able-to-find-it-at-this-online-retailer
# https://www.glovida.com/article/the-top-5-probiotic-brands-parents-are-buying-and-why-
# https://www.glovida.com/biogaia-probiotic-chewable-tabs-30-s.html
# HTTP Error 500: RuntimeError
# https://www.glovida.com/vivomixx-probiotics-caps-30-s.html
# https://www.glovida.com/lactokids-1641.html
# HTTP Error 404: Not Found
# https://www.glovida.com/lactogg-probiotics.html
# https://www.glovida.com/article/3-ways-to-build-your-child-s-immune-system
# https://www.glovida.com/article/all-the-hype-about-probiotics-does-it-work-or-is-it-just-marketing-hype
# https://www.glovida.com/article/4-essential-supplements-you-should-never-go-on-vacation-without
# https://www.glovida.com/searchanise/result?q=lactogg
# HTTP Error 404: Not Found
# https://www.glovida.com/searchanise/result?q=lacteol+fort
# HTTP Error 404: Not Found
# https://www.glovida.com/sambucol-black-elderberry-cold-flu-forte-capsules-24-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/ceramiracle-invi-sun-skin-defense-supplement-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/heliocare-oral-sunscreen-ultra-caps-30-s.html
# https://www.glovida.com/berocca-performance-orange-flavour-effervescent-tablets-30-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/sambucol-elderberry-lozenges-20-s.html
# HTTP Error 404: Not Found
# https://www.glovida.com/leftose-30-s-tablets-1834.html
# HTTP Error 404: Not Found
# https://www.glovida.com/category/new-arrivals
# https://www.glovida.com

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

# Get all the text files in the text directory
for file in os.listdir("text/" + "www." + domain + "/"):

    # Open the file and read the text
    with open("text/" + "www." + domain + "/" + file, "r") as f:
        text = f.read()

        # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
        texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()
# Out:
# /var/folders/2k/82sqqfjx4nb2z4z_3405zq3h0000gn/T/ipykernel_4131/2931785837.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   serie = serie.str.replace('\\n', ' ')
#                                                fname  \
# 0                             .com category body oil
# 1  .com products ZBE1006 berocca performance oran...
# 2                           .com brands?name=Isoderm
# 3                        .com brands?name=Rhinathiol
# 4  .com y not natural omega 369 oil australian em...
#
#                                                 text
# 0  .com category body oil.   Get 10% off first or...
# 1  .com products ZBE1006 berocca performance oran...
# 2  .com brands?name=Isoderm.  Glovida | Vitamins ...
# 3  .com brands?name=Rhinathiol.  Glovida | Vitami...
# 4  .com y not natural omega 369 oil australian em...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv('processed/scraped.csv', index_col=0)
df.columns = ['title', 'text']

# Tokenize the text and save the number of tokens to a new column
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
max_tokens = 500

# Function to split the text into chunks of a maximum number of tokens
def split_into_many(text, max_tokens = max_tokens):

    # Split the text into sentences
    sentences = text.split('. ')

    # Get the number of tokens for each sentence
    n_tokens = [len(tokenizer.encode(" " + sentence)) for sentence in sentences]
    
    chunks = []
    tokens_so_far = 0
    chunk = []

    # Loop through the sentences and tokens joined together in a tuple
    for sentence, token in zip(sentences, n_tokens):

        # If the number of tokens so far plus the number of tokens in the current sentence is greater 
        # than the max number of tokens, then add the chunk to the list of chunks and reset
        # the chunk and tokens so far
        if tokens_so_far + token > max_tokens:
            chunks.append(". ".join(chunk) + ".")
            chunk = []
            tokens_so_far = 0

        # If the number of tokens in the current sentence is greater than the max number of 
        # tokens, go to the next sentence
        if token > max_tokens:
            continue

        # Otherwise, add the sentence to the chunk and add the number of tokens to the total
        chunk.append(sentence)
        tokens_so_far += token + 1

    return chunks
    

shortened = []

# Loop through the dataframe
for row in df.iterrows():

    # If the text is None, go to the next row
    if row[1]['text'] is None:
        continue

    # If the number of tokens is greater than the max number of tokens, split the text into chunks
    if row[1]['n_tokens'] > max_tokens:
        shortened += split_into_many(row[1]['text'])
    
    # Otherwise, add the text to the list of shortened texts
    else:
        shortened.append( row[1]['text'] )

# %%
df = pd.DataFrame(shortened, columns = ['text'])
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
import openai

openai.api_key = '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'

df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
df.to_csv('processed/embeddings.csv')
df.head()
# Out:
#                                                 text  n_tokens  \
# 0                            .com category body oil.         5
# 1  .com products ZBE1006 berocca performance oran...        20
# 2  Retail Price:     S$29.85  3 FOR $21.35 EACH  ...       489
# 3                          .com brands?name=Isoderm.         9
# 4                       .com brands?name=Rhinathiol.         9
#
#                                           embeddings
# 0  [-0.011186306364834309, 0.005230539012700319, ...
# 1  [-0.0004889940028078854, -0.010559304617345333...
# 2  [-0.01358405128121376, -0.011433961801230907, ...
# 3  [0.002684955019503832, -0.005369910039007664, ...
# 4  [-0.0043905070051550865, -0.0099117960780859, ...

# %%
from openai.embeddings_utils import distances_from_embeddings

df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])

df.to_csv('processed/embeddings.csv')
df.head()
# Out:
#                                                 text  n_tokens  \
# 0                            .com category body oil.         5
# 1  .com products ZBE1006 berocca performance oran...        20
# 2  Retail Price:     S$29.85  3 FOR $21.35 EACH  ...       489
# 3                          .com brands?name=Isoderm.         9
# 4                       .com brands?name=Rhinathiol.         9
#
#                                           embeddings
# 0  [-0.011159648187458515, 0.005193239077925682, ...
# 1  [-0.0004889940028078854, -0.010559304617345333...
# 2  [-0.013721084222197533, -0.01135240588337183, ...
# 3  [0.002684955019503832, -0.005369910039007664, ...
# 4  [-0.00434370432049036, -0.00985968578606844, -...

# %%
import pandas as pd
import numpy as np
from openai.embeddings_utils import distances_from_embeddings, cosine_similarity

df=pd.read_csv('processed/embeddings.csv', index_col=0)
df['embeddings'] = df['embeddings'].apply(eval).apply(np.array)

df.head()
# Out:
#                                                 text  n_tokens  \
# 0                            .com category body oil.         5
# 1  .com products ZBE1006 berocca performance oran...        20
# 2  Retail Price:     S$29.85  3 FOR $21.35 EACH  ...       489
# 3                          .com brands?name=Isoderm.         9
# 4                       .com brands?name=Rhinathiol.         9
#
#                                           embeddings
# 0  [-0.011159648187458515, 0.005193239077925682, ...
# 1  [-0.0004889940028078854, -0.010559304617345333...
# 2  [-0.013721084222197533, -0.01135240588337183, ...
# 3  [0.002684955019503832, -0.005369910039007664, ...
# 4  [-0.00434370432049036, -0.00985968578606844, -...

# %%
def create_context(
    question, df, max_len=1800, size="ada"
):
    """
    Create a context for a question by finding the most similar context from the dataframe
    """

    # Get the embeddings for the question
    q_embeddings = openai.Embedding.create(input=question, engine='text-embedding-ada-002')['data'][0]['embedding']

    # Get the distances from the embeddings
    df['distances'] = distances_from_embeddings(q_embeddings, df['embeddings'].values, distance_metric='cosine')


    returns = []
    cur_len = 0

    # Sort by distance and add the text to the context until the context is too long
    for i, row in df.sort_values('distances', ascending=True).iterrows():
        
        # Add the length of the text to the current length
        cur_len += row['n_tokens'] + 4
        
        # If the context is too long, break
        if cur_len > max_len:
            break
        
        # Else add it to the text that is being returned
        returns.append(row["text"])

    # Return the context
    return "\n\n###\n\n".join(returns)

def answer_question(
    df,
    model="text-davinci-003",
    question="What are the benefits of taking Leftose tablets?",
    max_len=1800,
    size="ada",
    debug=False,
    max_tokens=150,
    stop_sequence=None
):
    """
    Answer a question based on the most similar context from the dataframe texts
    """
    context = create_context(
        question,
        df,
        max_len=max_len,
        size=size,
    )
    # If debug, print the raw model response
    if debug:
        print("Context:\n" + context)
        print("\n\n")

    try:
        # Create a completions using the question and context
        response = openai.Completion.create(
            prompt=f"Answer the question based on the context below, and if the question can't be answered based on the context, say \"I don't know\"\n\nContext: {context}\n\n---\n\nQuestion: {question}\nAnswer:",
            temperature=0,
            max_tokens=max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=stop_sequence,
            model=model,
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
answer_question(df, question="What day is it?", debug=False)
# Out:
# "I don't know."

# %%
answer_question(df, question="What is the expiry for heliocare purewhite radiance max")
# Out:
# '31-Jul-2024'
