# %% [markdown]
# # Getting Started with OpenAI Evals

# %% [markdown]
# The hosted OpenAI Evals API lets you define evaluation data, model runs, and graders from Python. This notebook uses that hosted workflow end to end: we will create a small synthetic SQL dataset, register a custom eval, run the same examples through a model, and inspect the hosted run results.
#
# This notebook will cover:
# * Introduction to evaluation and hosted OpenAI Evals
# * Building an Eval
# * Running an Eval
# * Reviewing Eval results
#
# #### What are evaluations/ `evals`?
#
# Evaluation is the process of validating and testing the outputs that your LLM applications are producing. Having strong evaluations ("evals") will mean a more stable, reliable application that is resilient to code and model changes. An eval is a task used to measure the quality of the output of an LLM or LLM system. Given an input prompt, an output is generated. We evaluate this output with a set of ideal answers and find the quality of the LLM system.
#
# #### Importance of Evaluations
#
# If you are building with foundational models like `gpt-5.4`, creating high quality evals is one of the most impactful things you can do. Developing AI solutions involves an iterative design process. [Without evals, it can be very difficult and time intensive to understand](https://youtu.be/XGJNo8TpuVA?feature=shared&t=1089) how different model versions and prompts might affect your use case.
#
# With OpenAI's [continuous model upgrades](https://platform.openai.com/docs/models/continuous-model-upgrades), evals allow you to efficiently test model performance for your use cases in a standardized way. Developing a suite of evals customized to your objectives will help you quickly and effectively understand how new models may perform for your use cases. You can also make evals a part of your CI/CD pipeline to make sure you achieve the desired accuracy before deploying.
#
# #### Types of evals
#
# There are two main ways we can evaluate or grade completions: writing validation logic in code or using a model to inspect the answer. We will introduce each with some examples.
#
# **Writing logic for answer checking**
#
# The simplest and most common type of eval has an input and an ideal response or answer. For example, we can have an eval sample where the input is "What year was Obama elected president for the first time?" and the ideal answer is "2008". We feed the input to a model and get the completion. If the model says "2008", it is then graded as correct. We can write a string match to check if the completion includes the phrase "2008". If it does, we consider it correct.
#
# Consider another eval where the input is to generate valid JSON: we can write code that attempts to parse the completion as JSON and then considers the completion correct if it is parsable.
#
# **Model grading**
#
# In model grading, a model first answers the question, then a grader model inspects that response. For example, an input asks a model to write a funny joke. The model generates a completion. We then ask a grader model: "Is this joke funny? First reason step by step, then answer yes or no" and include the completion. We finally consider the original completion correct if the grader says yes.
#
# Model grading works best with a strong grader model and clear labels. It will still have an error rate, so it is important to validate grader performance with human evaluation before running evals at scale. For best results, it often makes sense to use a different model for grading from the one that produced the completion, such as using `gpt-5.4` to grade `gpt-5-mini` answers.
#
# #### Hosted OpenAI Evals
#
# Hosted evals are composed of a data source schema, a set of graders, and one or more runs. In this notebook, we will use a custom data source, generate model samples with the Evals API, and grade those samples with a label-model grader.

# %% [markdown]
# ### Getting Setup
#
# First, install the Python packages used by this notebook. The setup cell below installs the `openai` SDK for the hosted Evals API and `pandas` for result inspection.
#
# To run evals later in this notebook, you will need to set up and specify your OpenAI API key. After you obtain an API key, specify it using the `OPENAI_API_KEY` environment variable.
#
# Please be aware of the costs associated with using the API when running evals.

# %%
# %pip install openai pandas --quiet

from openai import OpenAI
import pandas as pd

client = OpenAI()

# %% [markdown]
# ## Building an evaluation with hosted OpenAI Evals
#
# At its core, an eval is a dataset, a model task, and one or more graders. To create a hosted eval, we need:
#
# 1. The test dataset as structured items.
# 2. A data source schema that describes those items.
# 3. A grader that can compare model outputs with the expected answers.
#
# ### Creating the eval dataset
#
# Let's create a dataset for a use case where we are evaluating the model's ability to generate syntactically correct SQLite SQL. In this use case, we have a series of tables that are related to car manufacturing.
#
# First we will need to create a system prompt that we would like to evaluate. We will pass in instructions for the model as well as an overview of the table structure:
# ```
# "TASK: Answer the following question with syntactically correct SQLite SQL. The SQL should be correct and be in context of the previous question-answer pairs.
# Table car_makers, columns = [*,Id,Maker,FullName,Country]
# Table car_names, columns = [*,MakeId,Model,Make]
# Table cars_data, columns = [*,Id,MPG,Cylinders,Edispl,Horsepower,Weight,Accelerate,Year]
# Table continents, columns = [*,ContId,Continent]
# Table countries, columns = [*,CountryId,CountryName,Continent]
# Table model_list, columns = [*,ModelId,Maker,Model]
# Foreign_keys = [countries.Continent = continents.ContId,car_makers.Country = countries.CountryId,model_list.Maker = car_makers.Id,car_names.Model = model_list.Model,cars_data.Id = car_names.MakeId]"
# ```
#
# For this prompt, we can ask a specific question:
# ```
# "How many car makers are there in Germany?"
# ```
#
# And we have an expected answer:
# ```
# "SELECT count ( * ) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country = T2.CountryId WHERE T2.CountryName = 'germany'"
# ```
#
# For the hosted eval run, each dataset row will be an `item` with fields for the prompt, question, and ideal SQL answer:
# ```
# {
#   "item": {
#     "input_prompt": "<system prompt>",
#     "question": "How many car makers are there in Germany?",
#     "ideal": "SELECT count ( * ) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country = T2.CountryId WHERE T2.CountryName = 'germany'"
#   }
# }
# ```
#
# One way to speed up the process of building eval datasets is to use `gpt-5.4` to generate synthetic data.

# %%
## Use gpt-5.4 to generate synthetic data
# Define the system prompt and user input (these should be filled as per the specific use case)
system_prompt = """You are a helpful assistant that can ask questions about a database table and write SQL queries to answer the question.
    A user will pass in a table schema and your job is to return a question answer pairing. The question should relevant to the schema of the table,
    and you can speculate on its contents. You will then have to generate a SQL query to answer the question. Below are some examples of what this should look like.

    Example 1
    ```````````
    User input: Table museum, columns = [*,Museum_ID,Name,Num_of_Staff,Open_Year]\nTable visit, columns = [*,Museum_ID,visitor_ID,Num_of_Ticket,Total_spent]\nTable visitor, columns = [*,ID,Name,Level_of_membership,Age]\nForeign_keys = [visit.visitor_ID = visitor.ID,visit.Museum_ID = museum.Museum_ID]\n
    Assistant Response:
    Q: How many visitors have visited the museum with the most staff?
    A: SELECT count ( * )  FROM VISIT AS T1 JOIN MUSEUM AS T2 ON T1.Museum_ID   =   T2.Museum_ID WHERE T2.Num_of_Staff   =   ( SELECT max ( Num_of_Staff )  FROM MUSEUM ) 
    ```````````

    Example 2
    ```````````
    User input: Table museum, columns = [*,Museum_ID,Name,Num_of_Staff,Open_Year]\nTable visit, columns = [*,Museum_ID,visitor_ID,Num_of_Ticket,Total_spent]\nTable visitor, columns = [*,ID,Name,Level_of_membership,Age]\nForeign_keys = [visit.visitor_ID = visitor.ID,visit.Museum_ID = museum.Museum_ID]\n
    Assistant Response:
    Q: What are the names who have a membership level higher than 4?
    A: SELECT Name   FROM VISITOR AS T1 WHERE T1.Level_of_membership   >   4 
    ```````````

    Example 3
    ```````````
    User input: Table museum, columns = [*,Museum_ID,Name,Num_of_Staff,Open_Year]\nTable visit, columns = [*,Museum_ID,visitor_ID,Num_of_Ticket,Total_spent]\nTable visitor, columns = [*,ID,Name,Level_of_membership,Age]\nForeign_keys = [visit.visitor_ID = visitor.ID,visit.Museum_ID = museum.Museum_ID]\n
    Assistant Response:
    Q: How many tickets of customer id 5?
    A: SELECT count ( * )  FROM VISIT AS T1 JOIN VISITOR AS T2 ON T1.visitor_ID   =   T2.ID WHERE T2.ID   =   5 
    ```````````
    """

user_input = "Table car_makers, columns = [*,Id,Maker,FullName,Country]\nTable car_names, columns = [*,MakeId,Model,Make]\nTable cars_data, columns = [*,Id,MPG,Cylinders,Edispl,Horsepower,Weight,Accelerate,Year]\nTable continents, columns = [*,ContId,Continent]\nTable countries, columns = [*,CountryId,CountryName,Continent]\nTable model_list, columns = [*,ModelId,Maker,Model]\nForeign_keys = [countries.Continent = continents.ContId,car_makers.Country = countries.CountryId,model_list.Maker = car_makers.Id,car_names.Model = model_list.Model,cars_data.Id = car_names.MakeId]"

messages = [{
        "role": "system",
        "content": system_prompt
    },
    {
        "role": "user",
        "content": user_input
    }
]

completion = client.chat.completions.create(
    model="gpt-5.4",
    messages=messages,
    temperature=0.7,
    n=5
)

for choice in completion.choices:
    print(choice.message.content + "\n")

# %% [markdown]
# Once we have the synthetic data, we need to convert it to match the format of the eval dataset.

# %%
eval_data = []
input_prompt = "TASK: Answer the following question with syntactically correct SQLite SQL. The SQL should be correct and be in context of the previous question-answer pairs.\nTable car_makers, columns = [*,Id,Maker,FullName,Country]\nTable car_names, columns = [*,MakeId,Model,Make]\nTable cars_data, columns = [*,Id,MPG,Cylinders,Edispl,Horsepower,Weight,Accelerate,Year]\nTable continents, columns = [*,ContId,Continent]\nTable countries, columns = [*,CountryId,CountryName,Continent]\nTable model_list, columns = [*,ModelId,Maker,Model]\nForeign_keys = [countries.Continent = continents.ContId,car_makers.Country = countries.CountryId,model_list.Maker = car_makers.Id,car_names.Model = model_list.Model,cars_data.Id = car_names.MakeId]"

for choice in completion.choices:
    generated_text = choice.message.content
    question = generated_text.split("Q: ")[1].split("\n")[0]
    answer = generated_text.split("\nA: ")[1].split("\n")[0]
    eval_data.append({
        "input_prompt": input_prompt,
        "question": question,
        "ideal": answer,
    })

for item in eval_data:
    print(item)

# %% [markdown]
# Next we need to create the hosted eval. The eval definition describes the item schema and the grader, while the run supplies the dataset rows and model configuration.
#
# For our SQL eval, each item has:
# * `input_prompt` - the system/developer instructions and database schema
# * `question` - the SQL question for the model
# * `ideal` - the reference SQL answer
#
# The grader will label each generated SQL response as `correct` or `incorrect` by comparing `{{sample.output_text}}` with `{{item.ideal}}` in the context of the original question.

# %%
sql_eval = client.evals.create(
    name="car-maker-sql-correctness",
    data_source_config={
        "type": "custom",
        "item_schema": {
            "type": "object",
            "properties": {
                "input_prompt": {"type": "string"},
                "question": {"type": "string"},
                "ideal": {"type": "string"},
            },
            "required": ["input_prompt", "question", "ideal"],
        },
        "include_sample_schema": True,
    },
    testing_criteria=[
        {
            "type": "label_model",
            "name": "SQL correctness grader",
            "model": "gpt-5.4",
            "input": [
                {
                    "role": "developer",
                    "content": (
                        "You are grading SQLite SQL answers. Label the submission correct "
                        "only if it answers the question using the supplied schema and is "
                        "semantically equivalent to the reference SQL. Minor formatting and "
                        "alias differences are acceptable."
                    ),
                },
                {
                    "role": "user",
                    "content": (
                        "Question: {{item.question}}\n\n"
                        "Reference SQL: {{item.ideal}}\n\n"
                        "Submitted SQL: {{sample.output_text}}\n\n"
                        "Return one label: correct or incorrect."
                    ),
                },
            ],
            "labels": ["correct", "incorrect"],
            "passing_labels": ["correct"],
        }
    ],
)

print(sql_eval.id)

# %% [markdown]
# ## Running an evaluation
#
# We can run this eval with the hosted Evals API. The run below uses the synthetic car-maker SQL examples we just created and sends the `input_prompt` and `question` fields to the model under test.
#
# This notebook uses `gpt-5-mini` as the evaluated model and `gpt-5.4` as the grader model. Running the cells that call the API requires `OPENAI_API_KEY` and will incur API usage.

# %% [markdown]
# The run response includes a hosted `report_url`, status, and result counts. We poll until the run leaves a queued or in-progress state so the analysis cells inspect the run created in this notebook.

# %% [markdown]
# The `data_source` for this run uses `file_content`, so the notebook passes the generated `eval_data` directly to the API.

# %%
import time

run = client.evals.runs.create(
    sql_eval.id,
    name="gpt-5-mini car-maker SQL run",
    data_source={
        "type": "responses",
        "model": "gpt-5-mini",
        "input_messages": {
            "type": "template",
            "template": [
                {"role": "developer", "content": "{{item.input_prompt}}"},
                {"role": "user", "content": "{{item.question}}"},
            ],
        },
        "sampling_params": {
            "max_completions_tokens": 512,
        },
        "source": {
            "type": "file_content",
            "content": [{"item": item} for item in eval_data],
        },
    },
)

terminal_statuses = {"completed", "failed", "cancelled", "canceled"}
while run.status not in terminal_statuses:
    time.sleep(5)
    run = client.evals.runs.retrieve(run.id, eval_id=sql_eval.id)

run_summary = {
    "eval_id": sql_eval.id,
    "run_id": run.id,
    "status": run.status,
    "report_url": run.report_url,
    "result_counts": run.result_counts,
    "per_testing_criteria_results": run.per_testing_criteria_results,
}
display(run_summary)

# %% [markdown]
# You can create additional runs against the same eval by calling `client.evals.runs.create(...)` again with a different model, prompt template, or dataset. This lets you compare prompt and model changes while keeping the grader and data schema stable.

# %% [markdown]
# ### Going through eval results
#
# The hosted Evals API stores run results for the run ID returned above. We can inspect the run summary and fetch output items directly from the API.

# %%
run = client.evals.runs.retrieve(run.id, eval_id=sql_eval.id)
display({
    "id": run.id,
    "status": run.status,
    "report_url": run.report_url,
    "result_counts": run.result_counts,
})

# %%
output_items = list(client.evals.runs.output_items.list(
    run.id,
    eval_id=sql_eval.id,
    limit=20,
))

sample_errors = [
    item.model_dump().get("sample", {}).get("error")
    for item in output_items
    if item.model_dump().get("sample", {}).get("error")
]
if sample_errors:
    raise RuntimeError(f"Hosted Evals returned sample errors: {sample_errors[:3]}")

output_items_df = pd.DataFrame([item.model_dump() for item in output_items])
display(output_items_df.head())

# %% [markdown]
# Each output item contains the input item, model sample, and grader results for a row in the eval run.

# %%
display(output_items_df.columns.tolist())

# %% [markdown]
# Let's also look at the overall result counts from the hosted run.

# %%
display(run.result_counts)

# %% [markdown]
# We can review individual output items to understand the input, generated SQL, and grader outcome.

# %%
pd.set_option("display.max_colwidth", None)
if len(output_items_df) > 0:
    display(output_items_df.iloc[0].to_frame(name="value"))
else:
    print("No output items returned for this run.")

# %%
def sample_output_text(sample):
    if not isinstance(sample, dict):
        return sample
    if "output_text" in sample:
        return sample["output_text"]
    outputs = sample.get("output", [])
    text_parts = [output.get("content", "") for output in outputs if isinstance(output, dict)]
    return "\n".join(part for part in text_parts if part) or sample


# Inspect generated samples
for item in output_items[:5]:
    item_dict = item.model_dump()
    datasource_item = item_dict.get("datasource_item", {}) or item_dict.get("item", {})
    sample = item_dict.get("sample", {})
    print(f"Question: {datasource_item.get('question', 'Question not available')}")
    print(f"Expected: {datasource_item.get('ideal', 'Reference SQL not available')}")
    print(f"Sampled: {sample_output_text(sample)}")
    print("-" * 10)

# %% [markdown]
# Let's review any failures to understand which tests did not succeed.

# %%
def display_output_item(item):
    item_dict = item.model_dump()
    datasource_item = item_dict.get("datasource_item", {}) or item_dict.get("item", {})
    sample = item_dict.get("sample", {})
    results = item_dict.get("results", [])

    from IPython.display import HTML, display

    display(HTML(f"<b>QUESTION</b><br>{datasource_item.get('question', 'Question not available')}"))
    display(HTML(f"<b>EXPECTED</b><br>{datasource_item.get('ideal', 'Reference SQL not available')}"))
    display(HTML(f"<b>SUBMISSION</b><br>{sample_output_text(sample)}"))
    display(HTML(f"<b>GRADER RESULTS</b><br>{results}"))

# %%
for item in output_items:
    item_dict = item.model_dump()
    status = item_dict.get("status") or item_dict.get("result")
    if status == "fail":
        display_output_item(item)
        print("-" * 40)

# %% [markdown]
# Reviewing the failed examples can show whether the model made a SQL mistake or the grader was too strict. For SQL tasks, exact string matches are often too brittle because correct answers may use different aliases, formatting, or join order. A model grader is useful here, but it should still be spot-checked against human judgment before you use the eval as a production gate.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Building out effective evals is a core part of the development cycle of LLM-based applications. Hosted OpenAI Evals provide the structure for defining datasets, running model variants, and inspecting grader results without switching to a separate registry or local log format.
#
# The example shown in this guide is a straightforward use case for evals. As you continue to explore this workflow, consider expanding the dataset with real user examples, adding deterministic syntax checks, and comparing additional model or prompt variants against the same eval.
