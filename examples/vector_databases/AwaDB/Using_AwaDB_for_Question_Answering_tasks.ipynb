# %% [markdown]
# # Using AwaDB as a Vector database for Question Answering tasks
#
# This notebook is an example for how you can use AwaDB as the vector database to save embedding gained from OpenAI Embedding. Then use GPT and embedding-based search to do question answering tasks
#
# We will provide an end-to-end workflow example to illustrate the entire process.
#
# 1. Text Preprocessing
# 2. Embedding
# 3. Vector Store
# 4. Similarity Search
# 5. Question Answering
#
# ```mermaid
# graph LR
#   A[Text Preprocessing] --> B[Embedding]
#   B --> C[Vector Store]
#   C --> D[Similarity Search]
#   D --> E[Question Answering]
# ```
#
# ## Install libraries
# The requirments for this sample is `openai` and `awadb` packages
#
# You can use `pip install awadb` and `pip install openai` to install them.

# %%
# Import necessary libraries

try:
    import openai
    import awadb
except ImportError as exc:
    raise ImportError(
        "Could not import libraries. "
        "Please install it with `pip install awadb` or `pip install openai`"
    ) from exc

# %% [markdown]
# You also need to set your openai api key as environment variable before. You can find more information abou this by refering [Best Practices for API Key Safety
# ](https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety)

# %%
import os
import wget

assert os.environ["OPENAI_API_KEY"] != None

# %% [markdown]
# ## Load Dataset
#
# We then need to load the dataset we are used in this example.

# %%
embeddings_path = "https://raw.githubusercontent.com/awa-ai/awadb/main/tests/state_of_the_union.txt"
file_path = "state_of_the_union.txt"

if not os.path.exists(file_path):
    wget.download(embeddings_path, file_path)
    print("\nFile downloaded successfully.")
else:
    print("File already exists in the local file system.")
    
# Load the data file
from langchain.document_loaders import TextLoader
loader = TextLoader(file_path)
# Out:
# File already exists in the local file system.

# %% [markdown]
# ### Split the text
# Then we are going to preprocessing the text. Briefly, we split the text data into chunks of size 40, with an overlap of size 5 between neighboring chunks

# %%
# Transform to document
data = loader.load()
print(f'documents:{len(data)}')

# Initialize tex spilitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=40, chunk_overlap=5)
# Split the document
split_docs = text_splitter.split_documents(data)
print("split_docs size:",len(split_docs))
# Out:
# Created a chunk of size 164, which is longer than the specified 40
# Created a chunk of size 75, which is longer than the specified 40
# Created a chunk of size 95, which is longer than the specified 40
# Created a chunk of size 71, which is longer than the specified 40
# Created a chunk of size 78, which is longer than the specified 40
# Created a chunk of size 169, which is longer than the specified 40
# Created a chunk of size 122, which is longer than the specified 40
# Created a chunk of size 121, which is longer than the specified 40
# Created a chunk of size 139, which is longer than the specified 40
# Created a chunk of size 181, which is longer than the specified 40
# Created a chunk of size 101, which is longer than the specified 40
# Created a chunk of size 113, which is longer than the specified 40
# Created a chunk of size 129, which is longer than the specified 40
# Created a chunk of size 70, which is longer than the specified 40
# Created a chunk of size 100, which is longer than the specified 40
# Created a chunk of size 59, which is longer than the specified 40
# Created a chunk of size 66, which is longer than the specified 40
# Created a chunk of size 66, which is longer than the specified 40
# Created a chunk of size 43, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 136, which is longer than the specified 40
# Created a chunk of size 189, which is longer than the specified 40
# Created a chunk of size 41, which is longer than the specified 40
# Created a chunk of size 69, which is longer than the specified 40
# Created a chunk of size 215, which is longer than the specified 40
# Created a chunk of size 124, which is longer than the specified 40
# Created a chunk of size 82, which is longer than the specified 40
# Created a chunk of size 84, which is longer than the specified 40
# Created a chunk of size 118, which is longer than the specified 40
# Created a chunk of size 129, which is longer than the specified 40
# Created a chunk of size 128, which is longer than the specified 40
# Created a chunk of size 114, which is longer than the specified 40
# Created a chunk of size 155, which is longer than the specified 40
# Created a chunk of size 232, which is longer than the specified 40
# Created a chunk of size 139, which is longer than the specified 40
# Created a chunk of size 163, which is longer than the specified 40
# Created a chunk of size 68, which is longer than the specified 40
# Created a chunk of size 113, which is longer than the specified 40
# Created a chunk of size 109, which is longer than the specified 40
# Created a chunk of size 142, which is longer than the specified 40
# Created a chunk of size 178, which is longer than the specified 40
# Created a chunk of size 162, which is longer than the specified 40
# Created a chunk of size 138, which is longer than the specified 40
# Created a chunk of size 145, which is longer than the specified 40
# Created a chunk of size 173, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 190, which is longer than the specified 40
# Created a chunk of size 152, which is longer than the specified 40
# Created a chunk of size 172, which is longer than the specified 40
# Created a chunk of size 115, which is longer than the specified 40
# Created a chunk of size 53, which is longer than the specified 40
# Created a chunk of size 128, which is longer than the specified 40
# Created a chunk of size 133, which is longer than the specified 40
# Created a chunk of size 242, which is longer than the specified 40
# Created a chunk of size 151, which is longer than the specified 40
# Created a chunk of size 129, which is longer than the specified 40
# Created a chunk of size 105, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 100, which is longer than the specified 40
# Created a chunk of size 106, which is longer than the specified 40
# Created a chunk of size 138, which is longer than the specified 40
# Created a chunk of size 156, which is longer than the specified 40
# Created a chunk of size 99, which is longer than the specified 40
# Created a chunk of size 59, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 142, which is longer than the specified 40
# Created a chunk of size 100, which is longer than the specified 40
# Created a chunk of size 67, which is longer than the specified 40
# Created a chunk of size 185, which is longer than the specified 40
# Created a chunk of size 46, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 219, which is longer than the specified 40
# Created a chunk of size 138, which is longer than the specified 40
# Created a chunk of size 173, which is longer than the specified 40
# Created a chunk of size 83, which is longer than the specified 40
# Created a chunk of size 141, which is longer than the specified 40
# Created a chunk of size 106, which is longer than the specified 40
# Created a chunk of size 69, which is longer than the specified 40
# Created a chunk of size 52, which is longer than the specified 40
# Created a chunk of size 83, which is longer than the specified 40
# Created a chunk of size 133, which is longer than the specified 40
# Created a chunk of size 108, which is longer than the specified 40
# Created a chunk of size 47, which is longer than the specified 40
# Created a chunk of size 46, which is longer than the specified 40
# Created a chunk of size 172, which is longer than the specified 40
# Created a chunk of size 84, which is longer than the specified 40
# Created a chunk of size 120, which is longer than the specified 40
# Created a chunk of size 114, which is longer than the specified 40
# Created a chunk of size 304, which is longer than the specified 40
# Created a chunk of size 44, which is longer than the specified 40
# Created a chunk of size 125, which is longer than the specified 40
# Created a chunk of size 128, which is longer than the specified 40
# Created a chunk of size 93, which is longer than the specified 40
# Created a chunk of size 124, which is longer than the specified 40
# Created a chunk of size 71, which is longer than the specified 40
# Created a chunk of size 138, which is longer than the specified 40
# Created a chunk of size 122, which is longer than the specified 40
# Created a chunk of size 175, which is longer than the specified 40
# Created a chunk of size 65, which is longer than the specified 40
# Created a chunk of size 86, which is longer than the specified 40
# Created a chunk of size 143, which is longer than the specified 40
# Created a chunk of size 137, which is longer than the specified 40
# Created a chunk of size 82, which is longer than the specified 40
# Created a chunk of size 150, which is longer than the specified 40
# Created a chunk of size 61, which is longer than the specified 40
# Created a chunk of size 137, which is longer than the specified 40
# Created a chunk of size 83, which is longer than the specified 40
# Created a chunk of size 58, which is longer than the specified 40
# Created a chunk of size 65, which is longer than the specified 40
# Created a chunk of size 50, which is longer than the specified 40
# Created a chunk of size 126, which is longer than the specified 40
# Created a chunk of size 116, which is longer than the specified 40
# Created a chunk of size 125, which is longer than the specified 40
# Created a chunk of size 123, which is longer than the specified 40
# Created a chunk of size 79, which is longer than the specified 40
# Created a chunk of size 130, which is longer than the specified 40
# Created a chunk of size 78, which is longer than the specified 40
# Created a chunk of size 143, which is longer than the specified 40
# Created a chunk of size 66, which is longer than the specified 40
# Created a chunk of size 70, which is longer than the specified 40
# Created a chunk of size 177, which is longer than the specified 40
# Created a chunk of size 50, which is longer than the specified 40
# Created a chunk of size 116, which is longer than the specified 40
# Created a chunk of size 95, which is longer than the specified 40
# Created a chunk of size 47, which is longer than the specified 40
# Created a chunk of size 78, which is longer than the specified 40
# Created a chunk of size 41, which is longer than the specified 40
# Created a chunk of size 46, which is longer than the specified 40
# Created a chunk of size 47, which is longer than the specified 40
# Created a chunk of size 49, which is longer than the specified 40
# Created a chunk of size 55, which is longer than the specified 40
# Created a chunk of size 75, which is longer than the specified 40
# Created a chunk of size 72, which is longer than the specified 40
# Created a chunk of size 72, which is longer than the specified 40
# Created a chunk of size 166, which is longer than the specified 40
# Created a chunk of size 159, which is longer than the specified 40
# Created a chunk of size 124, which is longer than the specified 40
# Created a chunk of size 107, which is longer than the specified 40
# Created a chunk of size 113, which is longer than the specified 40
# Created a chunk of size 109, which is longer than the specified 40
# Created a chunk of size 84, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 148, which is longer than the specified 40
# Created a chunk of size 205, which is longer than the specified 40
# Created a chunk of size 96, which is longer than the specified 40
# Created a chunk of size 332, which is longer than the specified 40
# Created a chunk of size 102, which is longer than the specified 40
# Created a chunk of size 114, which is longer than the specified 40
# Created a chunk of size 215, which is longer than the specified 40
# Created a chunk of size 135, which is longer than the specified 40
# Created a chunk of size 112, which is longer than the specified 40
# Created a chunk of size 93, which is longer than the specified 40
# Created a chunk of size 127, which is longer than the specified 40
# Created a chunk of size 120, which is longer than the specified 40
# Created a chunk of size 90, which is longer than the specified 40
# Created a chunk of size 167, which is longer than the specified 40
# Created a chunk of size 124, which is longer than the specified 40
# Created a chunk of size 74, which is longer than the specified 40
# Created a chunk of size 169, which is longer than the specified 40
# Created a chunk of size 91, which is longer than the specified 40
# Created a chunk of size 203, which is longer than the specified 40
# Created a chunk of size 65, which is longer than the specified 40
# Created a chunk of size 122, which is longer than the specified 40
# Created a chunk of size 105, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 95, which is longer than the specified 40
# Created a chunk of size 59, which is longer than the specified 40
# Created a chunk of size 71, which is longer than the specified 40
# Created a chunk of size 43, which is longer than the specified 40
# Created a chunk of size 144, which is longer than the specified 40
# Created a chunk of size 76, which is longer than the specified 40
# Created a chunk of size 111, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 117, which is longer than the specified 40
# Created a chunk of size 128, which is longer than the specified 40
# Created a chunk of size 174, which is longer than the specified 40
# Created a chunk of size 54, which is longer than the specified 40
# Created a chunk of size 115, which is longer than the specified 40
# Created a chunk of size 186, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 181, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 52, which is longer than the specified 40
# Created a chunk of size 167, which is longer than the specified 40
# Created a chunk of size 119, which is longer than the specified 40
# Created a chunk of size 104, which is longer than the specified 40
# Created a chunk of size 90, which is longer than the specified 40
# Created a chunk of size 105, which is longer than the specified 40
# Created a chunk of size 96, which is longer than the specified 40
# Created a chunk of size 123, which is longer than the specified 40
# Created a chunk of size 139, which is longer than the specified 40
# Created a chunk of size 61, which is longer than the specified 40
# Created a chunk of size 175, which is longer than the specified 40
# Created a chunk of size 149, which is longer than the specified 40
# Created a chunk of size 106, which is longer than the specified 40
# Created a chunk of size 141, which is longer than the specified 40
# Created a chunk of size 167, which is longer than the specified 40
# Created a chunk of size 165, which is longer than the specified 40
# Created a chunk of size 110, which is longer than the specified 40
# Created a chunk of size 75, which is longer than the specified 40
# Created a chunk of size 98, which is longer than the specified 40
# Created a chunk of size 128, which is longer than the specified 40
# Created a chunk of size 115, which is longer than the specified 40
# Created a chunk of size 106, which is longer than the specified 40
# Created a chunk of size 115, which is longer than the specified 40
# Created a chunk of size 127, which is longer than the specified 40
# Created a chunk of size 86, which is longer than the specified 40
# Created a chunk of size 156, which is longer than the specified 40
# Created a chunk of size 118, which is longer than the specified 40
# Created a chunk of size 77, which is longer than the specified 40
# Created a chunk of size 186, which is longer than the specified 40
# Created a chunk of size 82, which is longer than the specified 40
# Created a chunk of size 119, which is longer than the specified 40
# Created a chunk of size 52, which is longer than the specified 40
# Created a chunk of size 83, which is longer than the specified 40
# Created a chunk of size 97, which is longer than the specified 40
# Created a chunk of size 140, which is longer than the specified 40
# Created a chunk of size 111, which is longer than the specified 40
# Created a chunk of size 130, which is longer than the specified 40
# Created a chunk of size 142, which is longer than the specified 40
# Created a chunk of size 88, which is longer than the specified 40
# Created a chunk of size 107, which is longer than the specified 40
# Created a chunk of size 184, which is longer than the specified 40
# Created a chunk of size 41, which is longer than the specified 40
# Created a chunk of size 168, which is longer than the specified 40
# Created a chunk of size 78, which is longer than the specified 40
# Created a chunk of size 101, which is longer than the specified 40
# Created a chunk of size 127, which is longer than the specified 40
# Created a chunk of size 281, which is longer than the specified 40
# Created a chunk of size 164, which is longer than the specified 40
# Created a chunk of size 88, which is longer than the specified 40
# Created a chunk of size 178, which is longer than the specified 40
# Created a chunk of size 169, which is longer than the specified 40
# Created a chunk of size 49, which is longer than the specified 40
# Created a chunk of size 106, which is longer than the specified 40
# Created a chunk of size 68, which is longer than the specified 40
# Created a chunk of size 109, which is longer than the specified 40
# Created a chunk of size 113, which is longer than the specified 40
# Created a chunk of size 201, which is longer than the specified 40
# Created a chunk of size 250, which is longer than the specified 40
# Created a chunk of size 139, which is longer than the specified 40
# Created a chunk of size 192, which is longer than the specified 40
# Created a chunk of size 325, which is longer than the specified 40
# Created a chunk of size 107, which is longer than the specified 40
# Created a chunk of size 123, which is longer than the specified 40
# Created a chunk of size 87, which is longer than the specified 40
# Created a chunk of size 132, which is longer than the specified 40
# Created a chunk of size 132, which is longer than the specified 40
# Created a chunk of size 147, which is longer than the specified 40
# Created a chunk of size 111, which is longer than the specified 40
# Created a chunk of size 101, which is longer than the specified 40
# Created a chunk of size 77, which is longer than the specified 40
# Created a chunk of size 127, which is longer than the specified 40
# Created a chunk of size 76, which is longer than the specified 40
# Created a chunk of size 120, which is longer than the specified 40
# Created a chunk of size 176, which is longer than the specified 40
# Created a chunk of size 177, which is longer than the specified 40
# Created a chunk of size 177, which is longer than the specified 40
# Created a chunk of size 242, which is longer than the specified 40
# Created a chunk of size 183, which is longer than the specified 40
# Created a chunk of size 92, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 181, which is longer than the specified 40
# Created a chunk of size 137, which is longer than the specified 40
# Created a chunk of size 125, which is longer than the specified 40
# Created a chunk of size 107, which is longer than the specified 40
# Created a chunk of size 123, which is longer than the specified 40
# Created a chunk of size 110, which is longer than the specified 40
# Created a chunk of size 182, which is longer than the specified 40
# Created a chunk of size 152, which is longer than the specified 40
# Created a chunk of size 162, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 135, which is longer than the specified 40
# Created a chunk of size 55, which is longer than the specified 40
# Created a chunk of size 153, which is longer than the specified 40
# Created a chunk of size 96, which is longer than the specified 40
# Created a chunk of size 54, which is longer than the specified 40
# Created a chunk of size 51, which is longer than the specified 40
# Created a chunk of size 114, which is longer than the specified 40
# Created a chunk of size 52, which is longer than the specified 40
# Created a chunk of size 65, which is longer than the specified 40
# Created a chunk of size 51, which is longer than the specified 40
# Created a chunk of size 77, which is longer than the specified 40
# Created a chunk of size 79, which is longer than the specified 40
# Created a chunk of size 140, which is longer than the specified 40
# Created a chunk of size 80, which is longer than the specified 40
# Created a chunk of size 51, which is longer than the specified 40
# Created a chunk of size 58, which is longer than the specified 40
# Created a chunk of size 59, which is longer than the specified 40
# Created a chunk of size 114, which is longer than the specified 40
# Created a chunk of size 109, which is longer than the specified 40
# Created a chunk of size 186, which is longer than the specified 40
# Created a chunk of size 44, which is longer than the specified 40
# Created a chunk of size 67, which is longer than the specified 40
# Created a chunk of size 73, which is longer than the specified 40
# Created a chunk of size 123, which is longer than the specified 40
# Created a chunk of size 146, which is longer than the specified 40
# Created a chunk of size 99, which is longer than the specified 40
# Created a chunk of size 101, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 95, which is longer than the specified 40
# Created a chunk of size 132, which is longer than the specified 40
# Created a chunk of size 83, which is longer than the specified 40
# Created a chunk of size 86, which is longer than the specified 40
# Created a chunk of size 55, which is longer than the specified 40
# Created a chunk of size 95, which is longer than the specified 40
# Created a chunk of size 68, which is longer than the specified 40
# Created a chunk of size 107, which is longer than the specified 40
# Created a chunk of size 51, which is longer than the specified 40
# Created a chunk of size 60, which is longer than the specified 40
# Created a chunk of size 103, which is longer than the specified 40
# Created a chunk of size 69, which is longer than the specified 40
# Created a chunk of size 98, which is longer than the specified 40
# Created a chunk of size 102, which is longer than the specified 40
# Created a chunk of size 47, which is longer than the specified 40
# Created a chunk of size 59, which is longer than the specified 40
# Created a chunk of size 67, which is longer than the specified 40
# documents:1
# split_docs size: 359

# %%
# Save the embedded texts by Awadb
"""
from langchain.vectorstores import AwaDB
db = AwaDB.from_documents(split_docs)

# Set the question
query = "What were the two main things the author worked on before college?"
# Similarity search results
similar_docs = db.similarity_search(query)
print(similar_docs)
"""

texts = [{'embeddingtext':text.page_content} for text in split_docs]

awadb_client = awadb.Client()
awadb_client.Create("testdb1")

awadb_client.Add(texts)

# Set the question
query = "What were the two main things the author worked on before college?"
# Similarity search results
similar_docs = awadb_client.Search(query, 3)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/9y/045hlg6s5hdcf_q60m8pk83c0000gn/T/ipykernel_51171/1108613981.py:23 in <module>    │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/9y/045hlg6s5hdcf_q60m8pk83c0000gn/T/ipykernel_51171/1108613981.py'                 │
# │                                                                                                  │
# │ /opt/homebrew/lib/python3.11/site-packages/awadb/__init__.py:1062 in Search                      │
# │                                                                                                  │
# │   1059 │   │   │   return show_results                                                           │
# │   1060 │   │                                                                                     │
# │   1061 │   │   vec_query = awa.VectorQuery()                                                     │
# │ ❱ 1062 │   │   vec_query.name = self.tables_vector_field_name[self.using_table_name]             │
# │   1063 │   │                                                                                     │
# │   1064 │   │   if query_type == FieldDataType.STRING:  # semantic text search                    │
# │   1065 │   │   │   embedding = self.llm.Embedding(query)                                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: 'testdb1'

# %% [markdown]
# ## Create Prompt
# We then will create prompts based on our question and the results from similarity serach.

# %%
# Create prompt
system_prompt = "You are a person who answers questions for people based on specified information\n"
similar_prompt = similar_docs[0].page_content + "\n" + similar_docs[1].page_content + "\n" + similar_docs[2].page_content + "\n"
question_prompt = f"Here is the question: {query}\nPlease provide an answer only related to the question and do not include any information more than that.\n"
prompt = system_prompt + "Here is some information given to you:\n" + similar_prompt + question_prompt
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/9y/045hlg6s5hdcf_q60m8pk83c0000gn/T/ipykernel_48152/4073646948.py:3 in <module>     │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/9y/045hlg6s5hdcf_q60m8pk83c0000gn/T/ipykernel_48152/4073646948.py'                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'similar_docs' is not defined

# %%
# Create response from gpt-3.5
response = openai.ChatCompletion.create(
  model = "gpt-3.5-turbo",
  temperature =  0.7,
  messages=[
        {"role": "system", "content": ""},
        {"role": "user", "content": prompt},
    ],
  max_tokens = 40
)

print(response['choices'][0]['message']['content'].replace(' .', '.').strip())
